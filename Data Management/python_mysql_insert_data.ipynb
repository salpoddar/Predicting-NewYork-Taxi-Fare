# %%
#import packages
import pandas as pd
import mysql.connector as mysql

# %%
#enter the credentials of mysql database connection
db = mysql.connect(
    host = "localhost",
    user = "root",
    passwd = "admin"
)

# %%
#read dataset into dataframe
df = pd.read_csv("train.csv")

# %%
#display dataframe
df.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count
# 0                1
# 1                1
# 2                2
# ...

# %%
df.shape
# Out:
# (55423856, 8)

# %%
df.head(13)
# Out:
#                               key  fare_amount          pickup_datetime  \
# 0     2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1     2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2    2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3     2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4   2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# 5     2011-01-06 09:50:45.0000002         12.1  2011-01-06 09:50:45 UTC
# 6     2012-11-20 20:35:00.0000001          7.5  2012-11-20 20:35:00 UTC
# 7    2012-01-04 17:22:00.00000081         16.5  2012-01-04 17:22:00 UTC
# 8   2012-12-03 13:10:00.000000125          9.0  2012-12-03 13:10:00 UTC
# 9    2009-09-02 01:11:00.00000083          8.9  2009-09-02 01:11:00 UTC
# 10    2012-04-08 07:30:50.0000002          5.3  2012-04-08 07:30:50 UTC
# 11   2012-12-24 11:24:00.00000098          5.5  2012-12-24 11:24:00 UTC
# ...

# %%
print(db)

# %%
#create a database cursor object
cursor=db.cursor(buffered=True)

# %%
#connect to table
cursor.execute("USE ibdproject")

# %%
#execute command and fetch all tables in given database
cursor.execute("SHOW TABLES") 
tables = cursor.fetchall()

# %%
print(tables)
# Out:
# [('fares',)]

# %%
# df.to_sql(con=db, name='ibdproject.fares', if_exists='append')

# %%
# !pip install pymysql
import pymysql
from sqlalchemy import create_engine

# %%
cnx = create_engine('mysql+pymysql://root:admin@localhost:3306/ibdproject', echo=False)

# data = pd.read_sql('SELECT * FROM sample_table', cnx)
# data.to_sql(name='sample_table2', con=cnx, if_exists = 'append', index=False)

# %%
# df.to_sql(name='ibdproject.fares', con=cnx, if_exists = 'append', index=False)

# %%
df3 = df.head(10000000)

# %%
df3.shape
# Out:
# (10000000, 8)

# %%
df3
# Out:
#                                    key  fare_amount          pickup_datetime  \
# 0          2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1          2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2         2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3          2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4        2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# 5          2011-01-06 09:50:45.0000002         12.1  2011-01-06 09:50:45 UTC
# 6          2012-11-20 20:35:00.0000001          7.5  2012-11-20 20:35:00 UTC
# 7         2012-01-04 17:22:00.00000081         16.5  2012-01-04 17:22:00 UTC
# 8        2012-12-03 13:10:00.000000125          9.0  2012-12-03 13:10:00 UTC
# 9         2009-09-02 01:11:00.00000083          8.9  2009-09-02 01:11:00 UTC
# 10         2012-04-08 07:30:50.0000002          5.3  2012-04-08 07:30:50 UTC
# ...

# %%
### insert all data into table 10M rows at a time

# %%
# df.to_csv('train.txt', header=True, index=False, sep='\t', mode='a')

# %%
df3.to_sql(name='ibdproject.fares', con=cnx, if_exists = 'append', index=False)

# %%
df4 = df.iloc[10000000:20000000]

# %%
df4.to_sql(name='ibdproject.fares', con=cnx, if_exists = 'append', index=False)

# %%
df5 = df.iloc[20000000:30000000]

# %%
df5.to_sql(name='ibdproject.fares', con=cnx, if_exists = 'append', index=False)

# %%
df6 = df.iloc[30000000:40000000]

# %%
df6.to_sql(name='ibdproject.fares', con=cnx, if_exists = 'append', index=False)

# %%
df7 = df.iloc[40000000:50000000]

# %%
df7.to_sql(name='ibdproject.fares', con=cnx, if_exists = 'append', index=False)

# %%
df8 = df.iloc[50000000:55423856]

# %%
df8.to_sql(name='ibdproject.fares', con=cnx, if_exists = 'append', index=False)
